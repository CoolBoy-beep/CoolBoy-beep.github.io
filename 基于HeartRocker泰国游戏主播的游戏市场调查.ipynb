# %% [markdown]
# <h1 style="text-align: center;">基于HeartRocker泰国游戏主播的游戏市场调查</h1>

# %% [markdown]
# <p style="text-align: justify;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;在当今数字化时代，网络游戏产业迅速蓬勃发展，成为各国经济体中不可忽视的重要组成部分。其中，泰国作为东南亚地区最具活力和潜力的游戏市场之一，备受广大玩家和投资者的关注。然而，要深入了解泰国游戏市场的现状和潜在机会，并为游戏行业的发展提供有力支持，仅凭直观的观察和经验是远远不够的。</p>

# %% [markdown]
# <img src="https://yt3.googleusercontent.com/ytc/AGIKgqNmXJsXa57FG3si9t10B0PSOb09t0eGIvLVs5jmUQ=s176-c-k-c0x00ffffff-no-rj" alt="HeartRocker">

# %% [markdown]
# <p style="text-align: center;">8.41 M 粉丝</p>

# %% [markdown]
# <h2 style="text-align: left;">HeartRocker的个人简介</h2>

# %% [markdown]
# <p style="text-align: justify;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;HeartRocker是一名泰国著名的游戏主播，也可算是一名老玩家，不论是游戏直播、游戏录播、视频恶搞剪辑等，他都曾做过。Youtube平台上显示他自2012年12月4日起就加入到Youtube平台上。当然，他不仅在Youtube上直播过，也在其他的平台上直播过，如 Twitch 平台。不过Youtube平台还是他扎根最久的一个平台了。在上大学期间，HeartRocker就开始通过在线视频平台分享自己的游戏经验和技巧（恶搞视频居多）。他尝试过扮演游戏角色，恶搞游戏剧情等方式来创作他的视频。由此可见，他的视频内容充满着古怪、搞笑、惊喜的元素。也因此，他的视频内容吸引了一大批观众，也逐渐积累了一定的粉丝基础。在他坚持不懈地努力下，他最终获得了一定的知名度。然后，随着直播平台的兴起，HeartRocker决定将游戏主播作为自己的职业。他放弃了其他工作机会，全身心地专注于游戏直播事业。对此，他还曾加入了一家专业的电子竞技团队，并在团队的支持下进一步发展自己的直播事业。HeartRocker选择了一些热门游戏作为自己直播的主要内容，例如《英雄联盟》、《绝地求生》和《守望先锋》等。他的幽默风格、精湛（搞笑）的游戏技巧和与观众的互动使他在游戏界迅速崭露头角。他的直播频道成为许多游戏迷的必看之处，吸引了大量的关注和订阅。他的幽默感和亲和力使他成为社交媒体上备受瞩目的人物，他的影响力迅速扩大。随着名气的增长，HeartRocker逐渐意识到自己的社会责任。他积极参与慈善活动，通过游戏直播筹集资金，支持儿童福利机构和其他慈善组织。他的慈善行为受到了粉丝和观众的广泛赞赏，并成为社会上的榜样。</p>

# %% [markdown]
# <h2 style="text-align: left;">泰国游戏市场趋势洞察分析</h2>

# %% [markdown]
# <p style="text-align: justify;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;各行各业的市场趋势，又或者可称之为市场需求倾向是行业内的每个玩家所必须关注的。玩家们可以针对不同时间段的市场需求倾向，制定满足或较为符合自己的目标锚定的策略，来提升自身在特定行业内的优势，如通过IP联名等方式，提高自身在特定行业的知名度，如Demon Slayor与各行各业的不同的商品或地点联合所举办的活动等；通过特定节假日的特性，制定一些优惠机制，吸引更多的客流量等。对于电商行业的卖家而言，关注市场需求的变动，把握时机达成交易，无疑是提升利润的最佳手段。对于游戏行业的主播也是如此，关注、适当迎合市场需求趋势无疑是能给予游戏主播一定的流量。新主播能通过关注、适当迎合市场需求趋势，创作符合自身风格标签的视频，将有助于新主播积累一定的粉丝量，其提升的效度将大于非关注市场需求变动趋势的投发情况。进一步，如果一个游戏主播能较好的把握市场需求变动倾向，对于其他各别渠道的合作方而言，也是选其合作的较好择选之一，因为它会一定程度上降低合作方的资金和精力的投入。</p>

# %% [markdown]
# <h3 style="text-align: left;">时间维度的市场需求倾向性分析</h3>

# %%
import pandas as pd
Trending=pd.read_csv('./Trending.csv')
Trending
# Out:
#     Unnamed: 0       View     Uploadtime                             Txt  \
# 0            0  155651000   10 years ago              Remake Tomb Raider
# 1            1  123278000    9 years ago                  Cry Of Fear Co
# 2            2  284334000    8 years ago                      LightDying
# 3            3  381194999    7 years ago                  Stardew Valley
# 4            4  346078000    6 years ago                Dead By Daylight
# 5            5   84065000    5 years ago  DETROIT The Hostage All Ending
# 6            6  274021000    2 years ago                        Impostor
# 7            7  162480000     1 year ago                       Fall Guys
# 8            8   21253000  10 months ago                   As Dusk Falls
# 9            9   11668000   9 months ago          The Mortuary Assistant
# 10          10   10200000   8 months ago           The Last Of Us Remake
# 11          11   17554000   7 months ago                 Shadows of Rose
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
import matplotlib.font_manager as font_manager
import seaborn as sns

chinese_font_path = './msyh.ttc'
chinese_font = font_manager.FontProperties(fname=chinese_font_path)
thai_font_path = "./leelawad.ttf"
thai_font = font_manager.FontProperties(fname=thai_font_path)

# 获取标签和计数
labels = Trending['Uploadtime']
counts = Trending['View']/1000000

# 创建数据框
df = pd.DataFrame({'Labels': labels, 'Counts': counts})

# 设置顺序
categories = df['Labels'].tolist()
df['Labels'] = pd.Categorical(df['Labels'], categories=categories[::-1], ordered=True)

# 创建柱状图
sns.barplot(data=df, x='Counts', y='Labels')
plt.yticks(fontproperties=thai_font)
plt.title('市场导向的游戏主题倾向（ 图 1 ）',fontproperties=chinese_font)
plt.xlabel("收视率",fontproperties=chinese_font)
plt.ylabel("上传时间",fontproperties=chinese_font)
# Out:
# Text(0, 0.5, '上传时间')

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

# 示例数据
labels = Trending['中文名称'][0:8]
sizes = counts[0:8]
num_colors = len(labels)
colors = plt.cm.Set3(np.linspace(0, 1, num_colors))

# 导入字体并创建字体属性
chinese_font = FontProperties(fname='./msyh.ttc')  # 将 /path/to/your/font.ttf 替换为你的字体文件路径
plt.rcParams['font.family'] = chinese_font.get_name()

# 绘制饼图
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)

# 设置标题
plt.title('市场导向的游戏关注分布图（ 图 2 ）', fontproperties=chinese_font)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

# 示例数据
labels = Trending['类型'][0:8]
sizes = counts[0:8]
num_colors = len(labels)
colors = plt.cm.Set3(np.linspace(0, 1, num_colors))

# 导入字体并创建字体属性
chinese_font = FontProperties(fname='./msyh.ttc')  # 将 /path/to/your/font.ttf 替换为你的字体文件路径
plt.rcParams['font.family'] = chinese_font.get_name()

# 绘制饼图
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)

# 设置标题
plt.title('市场导向的游戏关注分布图（ 图 3 ）', fontproperties=chinese_font)

# 显示图形
plt.show()

# %% [markdown]
# <p style="text-align: justify;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;从图 1 可见，在 HeartRocker 的 Youtube 平台上的投入视频当中，星露谷物语（角色动作类游戏）在 7 年前曾获得最高的收视率（381 Million）。其次是 6 年前的黎明死线（非对称竞技生存游戏）和 8 年前消逝的光芒(沙盒游戏)分别获得了将近 350 Million 和 290 Million 的收视率。它们各别占据整个游戏投入视频量的前三者 （21 %、19.1 %、15.7 %）。另外，结合以上两图可知，动作类游戏，尤其含有冒险、恐怖、不确定性等元素的游戏类型在 1 年以前是备受泰国游戏市场所关注的。当然，这并非表明含有这些元素的游戏类型在当今的泰国游戏市场已缺乏趣味性，其中可能因为竞争环境的变化所导致，更具趣味性的新类型游戏出现等因素导致目前的结果。</p>

# %% [markdown]
# <h2 style="text-align: left;">主播市场洞察力分析</h2>

# %%
import pandas as pd
VideoScraping=pd.read_csv('VideoScraping.csv')
Analysis1=pd.DataFrame({'Title':list(VideoScraping['title']),'View':list(VideoScraping['view']),'Uploadtime':list(VideoScraping['uploadtime'])})
for i in range(len(Analysis1['View'])):
    K=Analysis1['View'][i].split('views')[0]
    if 'K' in K:
        Analysis1['View'][i]=int(float(K.split('K')[0])*1000)
    if 'M' in K:
        Analysis1['View'][i]=int(float(K.split('M')[0])*1000000)
Eng=[]
for i in range(len(Analysis1['Title'])):
    Eng.append(re.sub("[\u0E00-\u0E7F\|,/:!#()~?...+]", "", Analysis1['Title'][i]).strip('【】').strip('[]').split("-")[0])
for i in range(len(Eng)):
    Eng[i]=Eng[i].strip(" ")
    if 'Live' in Eng[i]:
        Eng[i]=Eng[i].split("]")[1]
    if 'Q&A' in Eng[i]:
        Eng[i]=""

for i in range(len(Eng)):
    A=Eng[i].split(" ")
    for k in A:
        if k.isalpha():
            if "HRK" in k:
                Eng[i]=""
            elif "HBD" == k:
                Eng[i]=""
            elif "Basgamer" in k:
                Eng[i]=""
            elif "Professional" in k:
                Eng[i]=""
            elif "CPU" in k:
                Eng[i]=""
            elif "WoWs" == k:
                Eng[i]=""
            elif len(k) == 1:
                Eng[i]=""
            else:
                Eng[i]=''.join(Eng[i].strip(" "))
        elif k.isdigit():
            Eng[i]=""
        elif '400cc' in k:
            Eng[i]=""
        elif ']' in k:
            Eng[i]=Eng[i].split(']')[0]   
        else:
            Eng[i]=Eng[i]
T=pd.DataFrame(Eng)
value_counts = T[0].value_counts()
labels = value_counts.index[1:10]
counts = value_counts.values[1:10]
import matplotlib.pyplot as plt
import numpy as np
RMY=T
RMY.columns=['Txt']

# 示例数据
labels = labels
sizes = counts
num_colors = len(labels)
colors = plt.cm.Set3(np.linspace(0, 1, num_colors))
explode = (0.1, 0.05, 0.025, 0.0125, 0.00625, 0.003125, 0.0015625, 0.00078125, 0.000390625)  # 突出显示某个扇形块

# 绘制饼图
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)

# 设置标题
plt.title('主播自发投放的游戏分布图（图 4 ）',fontproperties=chinese_font)

# 显示图形
plt.show()

# %%
Trending=pd.read_csv('./Trending.csv')
Trending_as=Trending.sort_values('View',ascending=False)
Trending_as.reset_index().drop('index',axis=1).drop('Unnamed: 0',axis=1)
# Out:
#          View     Uploadtime                             Txt      中文名称  \
# 0   381194999    7 years ago                  Stardew Valley     星露谷物语
# 1   346078000    6 years ago                Dead By Daylight      黎明死线
# 2   284334000    8 years ago                      LightDying     消逝的光芒
# 3   274021000    2 years ago                        Impostor   冒名顶替者生存
# 4   162480000     1 year ago                       Fall Guys       糖豆人
# 5   155651000   10 years ago              Remake Tomb Raider      古墓丽影
# 6   123278000    9 years ago                  Cry Of Fear Co      恐惧之泣
# 7    84065000    5 years ago  DETROIT The Hostage All Ending  底特律：化身为人
# 8    24859000   6 months ago               God of War Ragnar   战神：诸神黄昏
# 9    21253000  10 months ago                   As Dusk Falls     黄昏降临时
# 10   17554000   7 months ago                 Shadows of Rose    生化危机村莊
# 11   16813000   2 months ago                 Hogwarts Legacy   霍格华兹的传承
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
import matplotlib.font_manager as font_manager
import seaborn as sns

chinese_font_path = './msyh.ttc'
chinese_font = font_manager.FontProperties(fname=chinese_font_path)
thai_font_path = "./leelawad.ttf"
thai_font = font_manager.FontProperties(fname=thai_font_path)

# 获取标签和计数
labels = Trending_as['Txt']
counts = Trending_as['View']/1000000

# 创建数据框
df = pd.DataFrame({'Labels': labels, 'Counts': counts})

# 创建柱状图
sns.barplot(data=df, x='Counts', y='Labels')
plt.yticks(fontproperties=thai_font)
plt.title('主播人为导向的游戏主题倾向（ 图 5 ）',fontproperties=chinese_font)
plt.xlabel("收视率",fontproperties=chinese_font)
plt.ylabel("上传时间",fontproperties=chinese_font)
# Out:
# Text(0, 0.5, '上传时间')

# %% [markdown]
# <p style="text-align: justify;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;基于 HeartRocker 针对某个游戏类型的视频投放量统计分析，可见 Stardew Valley（角色扮演游戏）的视频投放量是占据最多的，所获得的收视率也是最高的（ 381 Million ）。但其次的 God of War（动作冒险游戏）、南方公园：真理之杖 （动作冒险类游戏）所获得收视率不及于 Dead By DayLight(非对称竞技生存游戏) 【246 Million】和 Dying Light (沙盒游戏)【284 Million】。可见，HeartRocker 在 7 年前所投放的 Stardew Valley 是符合那个时期的泰国游戏市场需求倾向，也是正式为 HeartRocker 确定了一个游戏主播类型：角色扮演类游戏主播。再后来，主播也尝试通过不同类型的、含有互动性、情感共鸣性的游戏类型来获得更多的粉丝量，但结合图 4 和 图 5 的结果而言，HeartRocker 至少选对了两个游戏类型：Stardew Valley 和 Dying Light。</p>

# %% [markdown]
# <h2 style="text-align: left;">基于粉丝总评论的情感分析</h2>

# %%
import pandas as pd

data = {}  # 创建一个空字典来存储数据集

file_paths = []
for i in range(1, 1738):
    file_paths.append('SubVideos' + str(i) + '.csv')

for i, file_path in enumerate(file_paths):
    # 生成变量名
    variable_name = 'SubVideos{}'.format(i + 1)

    # 使用 pandas 读取 CSV 文件
    df = pd.read_csv(file_path)

    # 将读取的数据存储到字典中
    data[variable_name] = df

Y=0
for file_path in file_paths:
    k = file_path.strip('.csv')
    data[k].dropna(inplace=True)
    Y+=len(data[k])

print('总评论： '+str(Y))
# Out:
# 总评论： 270686

# %%
file=open('Trysentiment.txt','w')
for i in data['SubVideos1']['Comment']:
    file.write(i+'\n')
file.close()
for i in file_paths:
    k=i.strip('.csv')
    having_missing_na=data[k].isna().any().any()
    if having_missing_na:
        print('含有缺失值')
    else:
        continue
Y=0
for i in file_paths:
    k=i.strip('.csv')
    Y+=len(data[k].drop_duplicates('User'))
# 活跃粉丝
print('活跃粉丝： '+str(Y))
# Out:
# 活跃粉丝： 266083

# %%
import nltk
nltk.download('vader_lexicon')
from textblob import TextBlob
import pandas as pd

data = {}  # 创建一个空字典来存储数据集

file_paths = []
for i in range(1, 1738):
    file_paths.append('SubVideos' + str(i) + '.csv')

for i, file_path in enumerate(file_paths):
    # 生成变量名
    variable_name = 'SubVideos{}'.format(i + 1)

    # 使用 pandas 读取 CSV 文件
    df = pd.read_csv(file_path)

    # 将读取的数据存储到字典中
    data[variable_name] = df

pos_list = []
t_pos = []
neg_list = []
t_neg = []
mean_list = []
t_mean = []

# 基于 Microsoft 所给出的情感评分标准分类：Azure 官方网站 (https://learn.microsoft.com/en-us/azure/cognitive
#-services/language-service/sentiment-opinion-mining/how-to/call-api#sentiment-analysis)

for k in file_paths:
    l = k.strip('.csv')
    for i in range(len(data[l]['Comment'])):
        blob = TextBlob(str(data[l]['Comment'].iloc[i]))
        sentiment = blob.sentiment.polarity
        if sentiment > 0:
            pos_list.append('积极')
            t_pos.append(str(data[l]['Comment'].iloc[i]))
        elif sentiment < 0:
            neg_list.append('消极')
            t_neg.append(str(data[l]['Comment'].iloc[i]))
        else:
            mean_list.append('中性')
            t_mean.append(str(data[l]['Comment'].iloc[i]))

pos = pd.concat([pd.DataFrame(t_pos), pd.DataFrame(pos_list)], axis=1, keys=['text', 'class'])
neg = pd.concat([pd.DataFrame(t_neg), pd.DataFrame(neg_list)], axis=1, keys=['text', 'class'])
mean = pd.concat([pd.DataFrame(t_mean), pd.DataFrame(mean_list)], axis=1, keys=['text', 'class'])
sentiment = pd.concat([pos, neg, mean])
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
Try=pd.DataFrame(sentiment['class'])
F={'印象':['好印象','坏印象'],
   '量度':[Try[0].value_counts()[1],Try[0].value_counts()[2]]
  }
F1=pd.DataFrame(F)
F1
# Out:
#     印象     量度
# 0  好印象  27497
# 1  坏印象  12503

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
import matplotlib.font_manager as font_manager
import seaborn as sns

chinese_font_path = './msyh.ttc'
chinese_font = font_manager.FontProperties(fname=chinese_font_path)
thai_font_path = "./leelawad.ttf"
thai_font = font_manager.FontProperties(fname=thai_font_path)

# 获取标签和计数
labels = F1['印象']
counts = F1['量度']

# 创建数据框
df = pd.DataFrame({'Labels': counts, 'Counts': labels})

# 创建柱状图
sns.barplot(data=df, x='Counts', y='Labels')
plt.yticks(fontproperties=thai_font)
plt.title('主播印象倾向 （ 图 7 ）',fontproperties=chinese_font)
plt.xlabel("印象",fontproperties=chinese_font)
plt.ylabel("程度",fontproperties=chinese_font)
# Out:
# Text(0, 0.5, '程度')

# %% [markdown]
# <p style="text-align: justify;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;基于 HeartRocker 每一个视频底下的评论统计，可知 HeartRocker 游戏主播的活跃粉丝量达到 266083 数位，将近 30 万，但仅占比总粉丝量的 3.16 %。可见，HeartRocker 在粉丝互动性方面有待提高。不过基于总评论的情感分析，可见粉丝对于主播的好感度还是持有较高的水平，占据总体的 68.7 %</p>

# %% [markdown]
# <h2 style="text-align: left;">粉丝对视频内容的响应度分析</h2>

# %%
ADD = {}  # 创建一个空字典来存储数据集

file_pathsADD = []
for i in range(1, 1836):
    file_pathsADD.append('./ADDSubVideos' + str(i) + '.csv')

for i, file_path in enumerate(file_pathsADD):
    # 生成变量名
    variable_name = 'ADDSubVideos{}'.format(i + 1)

    # 使用 pandas 读取 CSV 文件
    df = pd.read_csv(file_path)

    # 将读取的数据存储到字典中
    ADD[variable_name] = df

# %%
sum=0
J=[]
for i in file_pathsADD:
    k=i.strip('.csv').split('/')[1]
    try:
        J.append(ADD[k]['Like'].iloc[0])
    except:
        J.append(0)
J=pd.DataFrame(J,columns=['Like'])
TryT=pd.DataFrame(T.value_counts(),columns=['Count'])[1:10]
TryT=TryT.reset_index()
TryT.rename(columns={0: 'Txt'}, inplace=True)
TryT
# Out:
#                              Txt  Count
# 0                 Stardew Valley     27
# 1            God of War Ragnarök     24
# 2  South Park The Stick Of Truth     19
# 3                Hogwarts Legacy     17
# 4                            PS4     15
# 5        Rise of the Tomb Raider     14
# 6                    Dying Light     14
# 7          The Last Of Us Remake     10
# 8                     GTA Online     10

# %%
M=Analysis1[1:1830]
Analysis5=pd.concat([M,J[1:1830],RMY[1:1830]],axis=1)

# %%
CLike=pd.DataFrame(Analysis5.groupby('Txt',as_index=False)["Like"].mean())

# %%
sum=0
OLike=[]
RLike=[]
for i in range(len(CLike)):
    for k in TryT['Txt']:
        if k == CLike['Txt'].iloc[sum]:
            OLike.append(CLike['Like'].iloc[sum])
            RLike.append(CLike['Txt'].iloc[sum])
    sum+=1  
Combind=pd.concat([pd.DataFrame(RLike),pd.DataFrame(OLike)],axis=1)
Combind.columns=['Title','Like']
Combind=Combind.drop(4)
Combind=Combind.reset_index().drop('index',axis=1)
Combind=Combind.sort_values('Like',ascending=False)
Combind.to_csv('./Combind.csv')
Combind
# Out:
#                            Title          Like
# 3                Hogwarts Legacy  37784.823529
# 7          The Last Of Us Remake  32298.900000
# 0                    Dying Light  29157.785714
# 2            God of War Ragnarök  25978.750000
# 6                 Stardew Valley  22767.333333
# 5  South Park The Stick Of Truth  22465.105263
# 1                     GTA Online  20585.000000
# 4        Rise of the Tomb Raider  11861.071429

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
import matplotlib.font_manager as font_manager
import seaborn as sns

chinese_font_path = './msyh.ttc'
chinese_font = font_manager.FontProperties(fname=chinese_font_path)
thai_font_path = "./leelawad.ttf"
thai_font = font_manager.FontProperties(fname=thai_font_path)

# 获取标签和计数
labels = Combind['Title'][0:3]
counts = Combind['Like'][0:3]

# 创建数据框
df = pd.DataFrame({'Labels': counts, 'Counts': labels})

# 创建柱状图
sns.barplot(data=df, x='Counts', y='Labels')
plt.yticks(fontproperties=thai_font)
plt.title('点赞柱状图 （ 图 8 ）',fontproperties=chinese_font)
plt.xlabel("游戏",fontproperties=chinese_font)
plt.ylabel("平均点赞数",fontproperties=chinese_font)
# Out:
# Text(0, 0.5, '平均点赞数')

# %% [markdown]
# <p style="text-align: justify;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;基于 HeartRocker 不同游戏类型视频的点赞统计，可见 Hogwarts Legay（角色扮演游戏）、最后生还者（第三人称射击）和 消逝的光芒（沙盒游戏）占据了粉丝平均点击量的前三者。可见，粉丝对于HeartRocker的主播定位倾向仍旧是角色扮演主播。</p>

# %% [markdown]
# <h2 style="text-align: left;">基于标题的视频点击率效果提升策略分析</h2>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
import matplotlib.font_manager as font_manager
import seaborn as sns

chinese_font_path = './msyh.ttc'
chinese_font = font_manager.FontProperties(fname=chinese_font_path)
thai_font_path = "./leelawad.ttf"
thai_font = font_manager.FontProperties(fname=thai_font_path)

T = []
for i in range(len(Analysis1['Title'])):
    T.append(re.sub("[^\u0E00-\u0E7F]", "", Analysis1['Title'][i]))

T = pd.DataFrame(T)
value_counts = T[0].value_counts()

# 获取标签和计数
labels = value_counts.index[1:30]
counts = value_counts.values[1:30]

# 创建数据框
df = pd.DataFrame({'Labels': labels, 'Counts': counts})

# 设置顺序
categories = df['Labels'].tolist()
df['Labels'] = pd.Categorical(df['Labels'], categories=categories[::-1], ordered=True)

# 创建柱状图
sns.barplot(data=df, x='Counts', y='Labels')
plt.yticks(fontproperties=thai_font)
plt.title('泰语标题倾向 （图 9）',fontproperties=chinese_font)
plt.xlabel("使用频率",fontproperties=chinese_font)
plt.ylabel("标题",fontproperties=chinese_font)
# Out:
# Text(0, 0.5, '标题')

# %% [markdown]
# <p style="text-align: justify;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;基于图 9，可见 HeartRocker 本身对于选题均含有搞笑、不正经的元素，常通过夸张描述的词汇或联想词，如 เจ้าหญิงวุ่นวายกับเจ้าชายโครงกระดูก 等来提高视频内容的点击量。</p>

# %% [markdown]
# <h2 style="text-align: left;">结论</h2>

# %% [markdown]
# <p style="text-align: justify;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;基于以上的综合分析，可知 HeartRocker 对于自身的定位是搞笑、不正经的角色扮演类主播，常玩的游戏类型均有刺激、恐怖、惊喜等元素。由此可见，如果合作方所运营的游戏类型是角色扮演、竞技游戏、恐怖游戏，可与 HeartRocker 进行密切的合作，拓展其游戏类型在泰国游戏市场的知名度。</p>

# %%
sum=0
for i in file_paths:
    k=i.strip('.csv')
    sum+=len(data[k])
print('总爬取的天数： 三天')
print('总爬取的数据量： '+str(sum+1840))
# Out:
# 总爬取的天数： 三天
# 总爬取的数据量： 1374539
